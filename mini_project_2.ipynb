# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\NARASIMHA\Downloads\student_data.csv")
df
# Out:
#       Name  Class Section  RollNo               Gmail  Marks
# 0     Amit     11       A       1     amit1@gmail.com     90
# 1   Anjali     12       C       2   anjali2@gmail.com     68
# 2    Rohit      8       C       3    rohit3@gmail.com     89
# 3    Sneha      8       C       4    sneha4@gmail.com     87
# 4    Rahul     12       A       5    rahul5@gmail.com     84
# 5    Rahul      8       B       6    rahul6@gmail.com     52
# 6   Anjali     11       A       7   anjali7@gmail.com     51
# 7     Neha      9       B       8     neha8@gmail.com     62
# 8    Rahul      8       A       9    rahul9@gmail.com     89
# 9   Anjali      8       B      10  anjali10@gmail.com     60
# 10   Rohit     10       B      11   rohit11@gmail.com     92
# 11  Anjali     10       C      12  anjali12@gmail.com     42
# 12   Priya     11       A      13   priya13@gmail.com     73
# 13    Neha      8       B      14    neha14@gmail.com     57
# ...

# %%
df.max()
# Out:
# Name                   Vikas
# Class                     12
# Section                    C
# RollNo                    20
# Gmail      vikas18@gmail.com
# Marks                     99
# dtype: object

# %%
df.min()
# Out:
# Name                  Amit
# Class                    8
# Section                  A
# RollNo                   1
# Gmail      amit1@gmail.com
# Marks                   42
# dtype: object

# %%
df["Marks"].mean()
# Out:
# 72.7

# %%
df["Marks"].mode()
# Out:
# 0    89
# 1    90
# Name: Marks, dtype: int64

# %%
df["Marks"].median()
# Out:
# 72.0

# %%
df["Marks"].var()
# Out:
# 298.74736842105267

# %%
df["Marks"].std()
# Out:
# 17.284309891374104

# %%
df["Marks"].cov(df["RollNo"])
# Out:
# -11.89473684210526
